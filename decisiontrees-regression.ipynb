# %%
'''

'''
# Out:
# '\n\n'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/kaggle/input/petrol-consumption/petrol_consumption.csv')
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                48 non-null     int64
#  2   Paved_Highways                48 non-null     int64
#  3   Population_Driver_licence(%)  48 non-null     float64
#  4   Petrol_Consumption            48 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
df.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
df.dtypes
# Out:
# Petrol_tax                      float64
# Average_income                    int64
# Paved_Highways                    int64
# Population_Driver_licence(%)    float64
# Petrol_Consumption                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
plt.figure(figsize=(24,20))

plt.subplot(4,2,1)
fig = df.boxplot(column='Petrol_tax',vert=False)
fig.set_title('')
#fig.set_ylabel('Petrol_tax')


plt.subplot(4,2,2)
fig = df.boxplot(column='Average_income',vert=False)
fig.set_title('')
#fig.set_ylabel('Average_income')


plt.subplot(4,2,3)
fig = df.boxplot(column='Paved_Highways',vert=False)
fig.set_title('')
#fig.set_ylabel('Paved_Highways')


plt.subplot(4,2,4)
fig = df.boxplot(column='Population_Driver_licence(%)',vert=False)
fig.set_title('')
#fig.set_ylabel('Population_Driver_licence(%)')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(12,5))
df.boxplot(patch_artist=True,vert=False)
#patch_artist used to fill the boxes with colors
#vert=False is used to create a horizontal boxplot
# Out:
# <Axes: >

# %%
#corelation
corr=df.corr()
corr
# Out:
#                               Petrol_tax  Average_income  Paved_Highways  \
# Petrol_tax                      1.000000        0.012665       -0.522130
# Average_income                  0.012665        1.000000        0.050163
# Paved_Highways                 -0.522130        0.050163        1.000000
# Population_Driver_licence(%)   -0.288037        0.157070       -0.064129
# Petrol_Consumption             -0.451280       -0.244862        0.019042
#
#                               Population_Driver_licence(%)  Petrol_Consumption
# Petrol_tax                                       -0.288037           -0.451280
# Average_income                                    0.157070           -0.244862
# Paved_Highways                                   -0.064129            0.019042
# Population_Driver_licence(%)                      1.000000            0.698965
# Petrol_Consumption                                0.698965            1.000000

# %%
plt.figure(figsize=(12,5))
sns.heatmap(corr,annot=True,linewidth=0.5)
plt.show()

# %%
# relation between petrol tax and petro consumption
pearson_coef, p_value = stats.pearsonr(df['Petrol_tax'], df['Petrol_Consumption'])
print("The Pearson Correlation Coefficient of Petrol_tax is", pearson_coef, " with a P-value of P =", p_value)
# pearson_coef measures the strength and direction of the linear relationship between the two variables
# Out:
# The Pearson Correlation Coefficient of Petrol_tax is -0.45128027518698666  with a P-value of P = 0.0012848906734289314

# %%
sns.regplot(x="Petrol_tax", y="Petrol_Consumption", data=df)
plt.ylim(0,)
# Out:
# (0.0, 999.2)

# %%
#average income and petrol consumption
pearson_coef, p_value = stats.pearsonr(df['Average_income'], df['Petrol_Consumption'])
print("The Pearson Correlation Coefficient of Average income is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient of Average income is -0.24486207498269905  with a P-value of P = 0.09346842977474587

# %%
sns.regplot(x="Average_income", y="Petrol_Consumption", data=df)
plt.ylim(0,)
# Out:
# (0.0, 999.2)

# %%
pearson_coef, p_value = stats.pearsonr(df['Paved_Highways'], df['Petrol_Consumption'])
print("The Pearson Correlation Coefficient of Paved_Highways is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient of Paved_Highways is 0.019041938819585748  with a P-value of P = 0.897784600249638

# %%
sns.regplot(x="Paved_Highways", y="Petrol_Consumption", data=df)
plt.ylim(0,)
# Out:
# (0.0, 999.2)

# %%
pearson_coef, p_value = stats.pearsonr(df['Population_Driver_licence(%)'], df['Petrol_Consumption'])
print("The Pearson Correlation Coefficient of Population_Driver_licence(%) is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient of Population_Driver_licence(%) is 0.6989654213627077  with a P-value of P = 3.2896049485308266e-08

# %%
sns.regplot(x="Population_Driver_licence(%)", y="Petrol_Consumption", data=df)
plt.ylim(0,)
# Out:
# (0.0, 999.2)

# %%
plt.figure(figsize=(12,5))

sns.histplot(x='Petrol_Consumption',data=df,kde=True,bins=20)
# Out:
# <Axes: xlabel='Petrol_Consumption', ylabel='Count'>

# %%
plt.figure(figsize=(24,20))
plt.subplot(4,2,1)
sns.histplot(x='Petrol_tax',data=df,kde=True,bins=20)  

plt.subplot(4,2,2)
sns.histplot(x='Average_income',data=df,kde=True,bins=20)  


plt.subplot(4,2,3)
sns.histplot(x='Paved_Highways',data=df,kde=True,bins=20)  


plt.subplot(4,2,4)
sns.histplot(x='Population_Driver_licence(%)',data=df,kde=True,bins=20)
# Out:
# <Axes: xlabel='Population_Driver_licence(%)', ylabel='Count'>

# %%
plt.figure(figsize=(12,5))
sns.histplot(x='Petrol_Consumption',data=df,kde=True)
# Out:
# <Axes: xlabel='Petrol_Consumption', ylabel='Count'>

# %%
# or
plt.figure(figsize=(12,5))
sns.displot(df['Petrol_Consumption'],kde=True)

# %%
x=df.drop(['Petrol_Consumption'],axis=1)
y=df['Petrol_Consumption']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_depth=4,max_features=4)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, max_features=4)

# %%
y_pred=tree.predict(x_test)

# %%
dt=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
dt.head(5)
# Out:
#     Actual  Predicted
# 29     534     553.75
# 4      410     467.25
# 26     577     595.00
# 30     571     595.00
# 32     577     595.00

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('r2_score:', metrics.r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error: 57.53333333333334
# Mean Squared Error: 5805.336111111112
# Root Mean Squared Error: 76.19275629028728
# r2_score: 0.009233627938657674

# %%
tree.feature_importances_
pd.Series(tree.feature_importances_,index=x.columns).sort_values(ascending=False)
# Out:
# Population_Driver_licence(%)    0.602183
# Average_income                  0.246799
# Paved_Highways                  0.112966
# Petrol_tax                      0.038053
# dtype: float64

# %%
from sklearn.tree import export_graphviz

# %%
dot_data = export_graphviz(tree, filled=True, 
                           rounded=True, 
                           feature_names=x.columns, 
                           out_file=None)

# %%
import graphviz

# %%
graphviz.Source(dot_data)

# %%
'''
Purity of the node increases with respect to the target variable
Decision tree splits the nodes on all available variables and then selects the split which results in most homogeneous sub-nodes
'''

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [{"max_depth":[3,4,5, None], "max_features":[3,4,5,6,7]}]

# %%
gs = GridSearchCV(estimator=DecisionTreeRegressor(random_state=123),param_grid = param_grid,cv=10)

# %%
gs.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=123),
#              param_grid=[{'max_depth': [3, 4, 5, None],
#                           'max_features': [3, 4, 5, 6, 7]}])

# %%
gs.cv_results_['params']
# Out:
# [{'max_depth': 3, 'max_features': 3},
#  {'max_depth': 3, 'max_features': 4},
#  {'max_depth': 3, 'max_features': 5},
#  {'max_depth': 3, 'max_features': 6},
#  {'max_depth': 3, 'max_features': 7},
#  {'max_depth': 4, 'max_features': 3},
#  {'max_depth': 4, 'max_features': 4},
#  {'max_depth': 4, 'max_features': 5},
#  {'max_depth': 4, 'max_features': 6},
#  {'max_depth': 4, 'max_features': 7},
#  {'max_depth': 5, 'max_features': 3},
#  {'max_depth': 5, 'max_features': 4},
#  {'max_depth': 5, 'max_features': 5},
#  {'max_depth': 5, 'max_features': 6},
#  {'max_depth': 5, 'max_features': 7},
#  {'max_depth': None, 'max_features': 3},
#  {'max_depth': None, 'max_features': 4},
#  {'max_depth': None, 'max_features': 5},
#  {'max_depth': None, 'max_features': 6},
#  {'max_depth': None, 'max_features': 7}]

# %%
gs.cv_results_['rank_test_score']
# Out:
# array([ 4,  9,  9,  9,  9,  2,  5,  5,  5,  5,  3, 13, 13, 13, 13,  1, 17,
#        17, 17, 17], dtype=int32)

# %%
gs.best_estimator_
# Out:
# DecisionTreeRegressor(max_features=3, random_state=123)

# %%
tree = DecisionTreeRegressor(max_depth=3,max_features=4)

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, max_features=4)

# %%
y_pred = tree.predict(x_test)

# %%
dt=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
dt.head(5)
# Out:
#     Actual   Predicted
# 29     534  547.800000
# 4      410  453.555556
# 26     577  617.312500
# 30     571  617.312500
# 32     577  617.312500

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('r2_score:', metrics.r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error: 56.86819444444444
# Mean Squared Error: 4890.384031828704
# Root Mean Squared Error: 69.93128078212713
# r2_score: 0.16538371724453127

# %%
from sklearn.tree import export_graphviz

# %%
dot_data = export_graphviz(tree, filled=True, 
                           rounded=True, 
                           feature_names=x.columns,
                           out_file=None)

# %%
import graphviz

# %%
graphviz.Source(dot_data)

# %%
DT_Regressor=[['Max_Depth',4,3],['Max_Feature',4,4],['Mean Abs. Error',57.53,58.86],['Mean Square Error',5805.33,4890.38],['Root Mean Square',76.19,69.93],['r2_Score',0.009,0.16]]
Result_Summary2= pd.DataFrame(DT_Regressor, columns = ['Parameters','Without Grid Search','With Grid Search'])
Result_Summary2
# Out:
#           Parameters  Without Grid Search  With Grid Search
# 0          Max_Depth                4.000              3.00
# 1        Max_Feature                4.000              4.00
# 2    Mean Abs. Error               57.530             58.86
# 3  Mean Square Error             5805.330           4890.38
# 4   Root Mean Square               76.190             69.93
# 5           r2_Score                0.009              0.16
